# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %% [markdown]
# ## Ejemplo de como funciona el programa.

# %% [markdown]
# Suma de dos matrices de 4x4.

# %%
# !cd  drive/MyDrive/Proyecto_CUDA_Programación_y_Analisis_Algoritmos/ && nvcc proyecto_cuda_programacion.cu && ./a.out
# Out:
# Bienvenido al programa para operar matrices.
# Ingresa el tamano de la primera matriz (A), ejemplo,
# para crear una matriz 5x7 ingresa 5 7
# 4 4
#  La matriz A es:
# 83 86 77 15
# 93 35 86 92
# 49 21 62 27
# 90 59 63 26
# Ingresa el tamano de la segunda matriz (B), ejemplo,
# para crear una matriz 5x7 ingresa 5 7
# 4 4
#  La matriz B es:
# 40 26 72 36
# 11 68 67 29
# 82 30 62 23
# 67 35 29 2
# Haz creado la matriz A y B. Ahora ingresa la operacion a realizar,ejemplos:
# A+B. |A-B. |A*B. |B*A. (Nota: con el punto)
# A+B.
# 123 112 149 51
# 104 103 153 121
# 131 51 124 50
# 157 94 92 28

# %% [markdown]
# Resta de matrices de 3x6

# %%
# !cd  drive/MyDrive/Proyecto_CUDA_Programación_y_Analisis_Algoritmos/ && nvcc proyecto_cuda_programacion.cu && ./a.out
# Out:
# Bienvenido al programa para operar matrices.
# Ingresa el tamano de la primera matriz (A), ejemplo,
# para crear una matriz 5x7 ingresa 5 7
# 3 6
#  La matriz A es:
# 83 86 77 15 93 35
# 86 92 49 21 62 27
# 90 59 63 26 40 26
# Ingresa el tamano de la segunda matriz (B), ejemplo,
# para crear una matriz 5x7 ingresa 5 7
# 3 6
#  La matriz B es:
# 72 36 11 68 67 29
# 82 30 62 23 67 35
# 29 2 22 58 69 67
# Haz creado la matriz A y B. Ahora ingresa la operacion a realizar,ejemplos:
# A+B. |A-B. |A*B. |B*A. (Nota: con el punto)
# A-B.
# 11 50 66 -53 26 6
# 4 62 -13 -2 -5 -8
# 61 57 41 -32 -29 -41

# %% [markdown]
# Multiplicación de dos matrices de 7x2 y 2x4.

# %%
# !cd  drive/MyDrive/Proyecto_CUDA_Programación_y_Analisis_Algoritmos/ && nvcc proyecto_cuda_programacion.cu && ./a.out
# Out:
# Bienvenido al programa para operar matrices.
# Ingresa el tamano de la primera matriz (A), ejemplo,
# para crear una matriz 5x7 ingresa 5 7
# 7 2
#  La matriz A es:
# 83 86
# 77 15
# 93 35
# 86 92
# 49 21
# 62 27
# 90 59
# Ingresa el tamano de la segunda matriz (B), ejemplo,
# para crear una matriz 5x7 ingresa 5 7
# 2 4
#  La matriz B es:
# 63 26 40 26
# 72 36 11 68
# Haz creado la matriz A y B. Ahora ingresa la operacion a realizar,ejemplos:
# A+B. |A-B. |A*B. |B*A. (Nota: con el punto)
# A*B.
# 11421 5254 4266 8006
# 5931 2542 3245 3022
# 8379 3678 4105 4798
# 12042 5548 4452 8492
# 4599 2030 2191 2702
# 5850 2584 2777 3448
# 9918 4464 4249 6352

# %% [markdown]
# ## Ejemplo de simulación: Multiplicación de matrices de 2000x1500 y 1500x2000
#
# Comparación de tiempo de ejecución para la multiplicación de dos matrices de 2000x1500 y 1500x2000.

# %%
# !cd  drive/MyDrive/Proyecto_CUDA_Programación_y_Analisis_Algoritmos/ && nvcc simulaciones.cu && ./a.out
# Out:
# Bienvenido al programa para operar matrices.
# Ingresa el tamano de la primera matriz (A), ejemplo,
# para crear una matriz 5x7 ingresa 5 7
# 2000 1500
# Ingresa el tamano de la segunda matriz (B), ejemplo,
# para crear una matriz 5x7 ingresa 5 7
# 1500 2000
# Haz creado la matriz A y B. Ahora ingresa la operacion a realizar,ejemplos:
# A+B. |A-B. |A*B. |B*A. (Nota: con el punto)
# B*A.
#
# CPU: 58.592, GPU: 4.3288
