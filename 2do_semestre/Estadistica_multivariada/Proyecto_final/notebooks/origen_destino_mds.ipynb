# %%
import pandas as pd
import numpy as np

# %%
origen = pd.read_csv("../data/processed/origen_destino_pasajeros.csv")

# %%
origen
# Out:
#            Origen         Destino    1992    1993    1994    1995    1996  \
# 0        Acapulco           Total  502483  478023  594812  428646  369129
# 1        Acapulco  Aguascalientes       0       0       0       0       0
# 2        Acapulco          Cancún     749    1297     723    1551    3514
# 3        Acapulco          Celaya       0       0       0       0       0
# 4        Acapulco       Chihuahua       0       0       0       0     519
# ...           ...             ...     ...     ...     ...     ...     ...
# 6823  Zihuatanejo         Windsor       0       0       0       0       0
# 6824  Zihuatanejo        Winnipeg    1336     112    1361       0       0
# 6825       Zúrich           Total       0     705    1518       0       0
# 6826       Zúrich          Cancún       0     705    1518       0       0
# 6827       Zúrich  Madrid-Barajas       0       0       0       0       0
#
#         1997    1998    1999  ...    2010    2011    2012    2013    2014  \
# ...
